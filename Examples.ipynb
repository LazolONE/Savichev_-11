# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0ad296f9-3a13-4a27-893b-0c6b79b4f03b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ad296f9-3a13-4a27-893b-0c6b79b4f03b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c7b59970-9e82-4fd0-8bef-423fd4725e31" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c7b59970-9e82-4fd0-8bef-423fd4725e31">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import first_other_one

text = first_other_one.read_text_file("Чук_и_Гек_отрывок.txt")

cleaned_text = first_other_one.clean_text(text)

word_counts = first_other_one.count_word_frequencies(cleaned_text)
print("Самые частые слова:", word_counts.most_common(10))

first_other_one.find_word_context(
    text=cleaned_text,
    target_word="Чук",
    left_len=5,
    right_len=5,
    cut_length=True,
    output_file="some_output_file.txt"
)
# Out:
# Самые частые слова: [('и', 121), ('не', 48), ('в', 47), ('на', 42), ('гек', 38), ('что', 37), ('а', 36), ('с', 27), ('чук', 27), ('они', 25)]
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# у него было двое – [ЧУК] и гек.
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9e6bbdc9-8e7a-4e01-bfa7-0cb1ed7bc28d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9e6bbdc9-8e7a-4e01-bfa7-0cb1ed7bc28d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from second_one import TFIDFCalculator
docs = [
    "In a hole in the ground there lived a hobbit. Not a nasty, dirty, wet hole, filled with the ends of worms and an oozy smell.",
    "It had perfectly good wallpaper, panelled rooms, tiled baths, handkerchiefs, and buttons, lots of underground halls, and the best of food and drink.",
    "Bilbo Baggins was a hobbit who liked to be quiet and comfortable, eating six meals a day, and thinking about breakfast or second breakfast.",
    "One morning the wizard Gandalf came by and changed Bilbo's life forever with just one simple question.",
    "Gandalf was looking for someone to share in an adventure, and though Bilbo did not want one, adventures soon found him anyway."
]

calculator = TFIDFCalculator(docs)

word = "hobbit"
doc_index = 2
tf_idf = calculator.get_tf_idf(word, doc_index, ignore_stopwords=True)

print(f"TF-IDF для слова '{word}' в документе {doc_index}: {tf_idf:.4f}")
# Out:
# TF-IDF для слова 'hobbit' в документе 2: 0.1312
